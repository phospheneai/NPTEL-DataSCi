# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./apy.csv')

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.groupby(['Season']).sum()
# Out:
#              Crop_Year          Area    Production
# Season
# Autumn         9931847  4.807113e+07  6.441377e+07
# Kharif       192433963  1.404845e+09  4.029970e+09
# Rabi         134375352  9.479874e+08  2.051688e+09
# Summer        29783876  7.598406e+07  1.706579e+08
# Whole Year   114886975  2.573005e+08  1.344248e+11
# Winter        12158683  2.195979e+08  4.345498e+08

# %%
4.029970e+09, 1.706579e+08, 6.441377e+07
# Out:
# (4029970000.0, 170657900.0, 64413770.0)

# %%
df_kharif = df[df['Season'].str.contains('Kharif')]

# %%
df_kharif.head()
# Out:
#                      State_Name District_Name  Crop_Year       Season  \
# 0   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 10  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 11  Andaman and Nicobar Islands      NICOBARS       2001  Kharif
#
#                    Crop    Area  Production
# 0              Arecanut  1254.0      2000.0
# 1   Other Kharif pulses     2.0         1.0
# 2                  Rice   102.0       321.0
# 10             Arecanut  1254.0      2061.0
# 11  Other Kharif pulses     2.0         1.0

# %%
df_kharif['Crop'].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Arhar/Tur', 'Bajra',
#        'Castor seed', 'Cotton(lint)', 'Dry chillies', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Korra', 'Maize', 'Moong(Green Gram)',
#        'Ragi', 'Sugarcane', 'Sunflower', 'Tobacco', 'Masoor', 'Sesamum',
#        'Urad', 'Gram', 'Onion', 'other misc. pulses', 'Samai',
#        'Small millets', 'Soyabean', 'Mesta', 'Cowpea(Lobia)',
#        'other oilseeds', 'Brinjal', 'Coriander', 'Grapes', 'Lemon',
#        'Linseed', 'Mango', 'Papaya', 'Pome Granet', 'Sapota', 'Tomato',
#        'Turmeric', 'Cabbage', 'Cashewnut', 'Potato', 'Sweet potato',
#        'Niger seed', 'Tapioca', 'Dry ginger', 'Safflower', 'Varagu',
#        'Jute', 'Orange', 'Blackgram', 'Sannhamp', 'Guar seed', 'Coconut ',
#        'Banana', 'Moth', 'Other Cereals & Millets', 'Pulses total',
#        'Peas & beans (Pulses)', 'Ginger', 'Garlic', 'Cond-spcs other',
#        'Wheat', 'Barley', 'Rapeseed &Mustard', 'Paddy', 'Black pepper',
# ...

# %%
df['Production'].argmax()
# Out:
# 178273

# %%
df.iloc[178273]
# Out:
# State_Name        Tamil Nadu
# District_Name     COIMBATORE
# Crop_Year               2011
# Season           Whole Year
# Crop                Coconut
# Area                   82704
# Production        1.2508e+09
# Name: 178273, dtype: object

# %%
df_tamilnadu = df[df['State_Name'].str.contains('Tamil Nadu')]

# %%
df_tamilnadu.head()
# Out:
#         State_Name District_Name  Crop_Year       Season       Crop     Area  \
# 177668  Tamil Nadu      ARIYALUR       2008  Kharif            Rice  24574.0
# 177669  Tamil Nadu      ARIYALUR       2008  Whole Year   Arhar/Tur    209.0
# 177670  Tamil Nadu      ARIYALUR       2008  Whole Year       Bajra    565.0
# 177671  Tamil Nadu      ARIYALUR       2008  Whole Year      Banana    190.0
# 177672  Tamil Nadu      ARIYALUR       2008  Whole Year   Cashewnut  31113.0
#
#         Production
# 177668         NaN
# 177669         NaN
# 177670         NaN
# 177671         NaN
# 177672         NaN

# %%
df_tamilnadu.groupby(['Crop_Year']).sum()
# Out:
#                  Area    Production
# Crop_Year
# 1997        9869675.0  3.369738e+08
# 1998       12253211.0  6.800716e+07
# 1999        6454857.0  5.675108e+07
# 2000        6298203.0  5.208971e+07
# 2001        4324672.0  4.159475e+07
# 2002        4673151.0  3.920144e+07
# 2003        4834735.0  3.490466e+07
# 2004        5160726.0  4.456710e+07
# 2005        5322577.0  5.246693e+07
# 2006        5085779.0  6.958519e+07
# 2007        5090960.0  5.803191e+07
# 2008        5071518.0  1.051235e+08
# 2009        4765920.0  5.363940e+07
# 2010        3615255.0  4.262919e+07
# 2011        4933432.0  6.260873e+09
# 2012        3122581.0  4.034128e+07
# 2013        5020615.0  4.719663e+09

# %%
6.260873e+09 > 4.719663e+09
# Out:
# True

# %%
df_bystate = df.groupby(['State_Name']).sum()

# %%
df_bystate['Production']
# Out:
# State_Name
# Andaman and Nicobar Islands    7.182232e+08
# Andhra Pradesh                 1.732459e+10
# Arunachal Pradesh              6.823913e+06
# Assam                          2.111752e+09
# Bihar                          3.664836e+08
# Chandigarh                     6.395650e+04
# Chhattisgarh                   1.009519e+08
# Dadra and Nagar Haveli         1.847871e+06
# Goa                            5.057558e+08
# Gujarat                        5.242913e+08
# Haryana                        3.812739e+08
# Himachal Pradesh               1.780517e+07
# Jammu and Kashmir              1.329102e+07
# Jharkhand                      1.077774e+07
# Karnataka                      8.634298e+08
# Kerala                         9.788005e+10
# Madhya Pradesh                 4.488407e+08
# Maharashtra                    1.263641e+09
# Manipur                        5.230917e+06
# Meghalaya                      1.211250e+07
# Mizoram                        1.661540e+06
# ...

# %%
df_bystate['Production'].argmax()
# Out:
# 15

# %%
df_bystate.iloc[15]
# Out:
# Crop_Year     8.546913e+06
# Area          3.190807e+07
# Production    9.788005e+10
# Name: Kerala, dtype: float64

# %%
area_col = df['Area']
production_col = df['Production']

# %%
area_col.corr(production_col)
# Out:
# 0.04058747919933999

# %%
df['Production'].mean()
# Out:
# 582503.4422509839

# %%
df['Production'].std()
# Out:
# 17065813.172410425

# %%
df_filled = df.fillna(-1111111)

# %%
df_2015 = df[df['Crop_Year'] == 2015]

# %%
df_2015[df['Production'] != -1111111]
# Out:
# <ipython-input-77-bd7b575ddcc8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2015[df['Production'] != -1111111]
#        State_Name  District_Name  Crop_Year       Season               Crop  \
# 147292     Odisha         ANUGUL       2015  Autumn               Groundnut
# 147293     Odisha         ANUGUL       2015  Autumn                   Maize
# 147294     Odisha         ANUGUL       2015  Autumn       Moong(Green Gram)
# 147295     Odisha         ANUGUL       2015  Autumn                    Ragi
# 147296     Odisha         ANUGUL       2015  Autumn                    Rice
# ...           ...            ...        ...          ...                ...
# 177663     Sikkim  WEST DISTRICT       2015  Kharif                Soyabean
# 177664     Sikkim  WEST DISTRICT       2015  Kharif                    Urad
# 177665     Sikkim  WEST DISTRICT       2015  Rabi                    Barley
# ...

# %%
df_2015['State_Name'].unique()
# Out:
# array(['Odisha', 'Sikkim'], dtype=object)

# %%
df_1997 = df[df['Crop_Year'] == 1997]

# %%
df_1997.head(10)
# Out:
#          State_Name District_Name  Crop_Year       Season          Crop  \
# 203  Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 204  Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 205  Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 206  Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 207  Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
# 208  Andhra Pradesh     ANANTAPUR       1997  Kharif          Groundnut
# 209  Andhra Pradesh     ANANTAPUR       1997  Kharif         Horse-gram
# 210  Andhra Pradesh     ANANTAPUR       1997  Kharif              Jowar
# 211  Andhra Pradesh     ANANTAPUR       1997  Kharif              Korra
# 212  Andhra Pradesh     ANANTAPUR       1997  Kharif              Maize
#
#          Area  Production
# 203   21400.0      2600.0
# 204    1400.0       500.0
# 205    1000.0       100.0
# 206    7300.0      9400.0
# 207    3700.0      7100.0
# ...

# %%
df_1997_grouped = df_1997.groupby(['Crop']).sum()

# %%
df_1997_grouped.sort_values('Production', ascending=False)
# Out:
#                        Crop_Year        Area   Production
# Crop
# Sugarcane                 659010   3482848.0  501229055.0
# Rice                     1212179  30706467.0   65848504.0
# Wheat                     728905  25640826.0   63831633.0
# Oilseeds total            163754  51751377.0   39245384.0
# Total foodgrain           215676  18974254.0   38843779.0
# Pulses total              201697  20720328.0   14410879.0
# Potato                    417373    941622.0   14095119.0
# Paddy                     351472   7885677.0   12551503.0
# Cotton(lint)              325511   5230253.0   10443524.0
# Jute                      147778    979700.0    9937985.0
# Maize                    1294056   5644113.0    9797054.0
# Banana                    191712    216302.0    8577683.0
# Jowar                     706938  10699683.0    7675581.0
# Bajra                     529205   9527424.0    7622765.0
# Tapioca                   149775    243461.0    6770940.0
# ...

# %%
df_crop_year = df['Crop_Year']
df_area = df['Area']
df_production = df['Production']

# %%
df_crop_year.head()
# Out:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: Crop_Year, dtype: int64

# %%
df_area.head()
# Out:
# 0    1254.0
# 1       2.0
# 2     102.0
# 3     176.0
# 4     720.0
# Name: Area, dtype: float64

# %%
df_production.head()
# Out:
# 0    2000.0
# 1       1.0
# 2     321.0
# 3     641.0
# 4     165.0
# Name: Production, dtype: float64

# %%
df_crop_year.corr(df_area) #Negative value, but maginitude of value is low, so no correlation
# Out:
# -0.026021527208407693

# %%
df_crop_year.corr(df_production)  #Positive value, but maginitude of value is low, so no correlation
# Out:
# 0.006989301430174885

# %%
df.groupby(['Crop_Year']).sum().sort_values('Production', ascending=False)
# Out:
#                    Area    Production
# Crop_Year
# 2011       1.536292e+08  1.430890e+10
# 2013       1.415249e+08  1.290359e+10
# 2006       1.706991e+08  8.681913e+09
# 2014       1.157575e+08  8.664541e+09
# 2004       1.678784e+08  8.189462e+09
# 2012       1.524698e+08  8.171055e+09
# 2005       1.631364e+08  8.043757e+09
# 2003       1.720881e+08  7.917974e+09
# 2008       1.712321e+08  7.717018e+09
# 2002       1.577690e+08  7.696955e+09
# 2009       1.656947e+08  7.660494e+09
# 2001       1.652956e+08  7.465541e+09
# 2000       1.652975e+08  7.449709e+09
# 2007       1.527242e+08  6.879442e+09
# 1999       1.586661e+08  6.434666e+09
# 2010       1.766192e+08  6.307609e+09
# 1998       1.669881e+08  5.825321e+09
# 1997       2.317150e+08  8.512329e+08
# 2015       4.601298e+06  6.935065e+06

# %%
df_tn = df[df['State_Name'].str.contains('Tamil Nadu')]

# %%
df_tn.head(5)
# Out:
#         State_Name District_Name  Crop_Year       Season       Crop     Area  \
# 177668  Tamil Nadu      ARIYALUR       2008  Kharif            Rice  24574.0
# 177669  Tamil Nadu      ARIYALUR       2008  Whole Year   Arhar/Tur    209.0
# 177670  Tamil Nadu      ARIYALUR       2008  Whole Year       Bajra    565.0
# 177671  Tamil Nadu      ARIYALUR       2008  Whole Year      Banana    190.0
# 177672  Tamil Nadu      ARIYALUR       2008  Whole Year   Cashewnut  31113.0
#
#         Production
# 177668         NaN
# 177669         NaN
# 177670         NaN
# 177671         NaN
# 177672         NaN

# %%
df_tn.groupby(['Crop']).sum().sort_values('Production', ascending=False)
# Out:
#            Crop_Year        Area    Production
# Crop
# Coconut       592047   3821909.0  1.093774e+10
# Sugarcane     966528   5284188.0  8.474968e+08
# Rice          998591  32386903.0  1.001227e+08
# Banana        875800   1379255.0  5.871609e+07
# Tapioca       775813   1501104.0  5.564865e+07
# ...              ...         ...           ...
# Papaya         64081       696.0  0.000000e+00
# Peach           8010        42.0  0.000000e+00
# Pear           12015      2676.0  0.000000e+00
# Plums          12016       809.0  0.000000e+00
# Yam            72090      1775.0  0.000000e+00
#
# [87 rows x 3 columns]

# %%
df_s = df_tn[df_tn['Crop'].str.contains('Coconut')]

# %%
df_s

# %%
len(df)
# Out:
# 246091
